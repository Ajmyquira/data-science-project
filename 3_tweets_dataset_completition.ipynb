# %% [markdown]
# This notebook is temporal. The goal is to generate and unique .cvs file with all tweets completed by day.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Reading all the tweets collected

# %%
import pandas as pd
import glob
import os

# Merging the files
files_joined = os.path.join('/content/drive/MyDrive/UCSP/Data-Science-Topics/Data', "tweets0*.csv")

# Return a list of all joined files
list_files = glob.glob(files_joined)

print("** Merging multiple csv files into a single pandas dataframe **")
# Merge files by joining all files
tweets = pd.concat(map(pd.read_csv, list_files), ignore_index=True)
tweets

# %%
tweets.shape
# Out:
# (2197456, 36)

# %%
tweets_filtered = pd.DataFrame(tweets[['date','tweet']])
tweets_filtered.columns = ['date','text']
tweets_filtered

# %%
type(tweets_filtered['date'][0])
# Out:
# str

# %%
# tweets_filtrered['date'] = pd.to_datetime(tweets_filtrered['date'])

# %%
tweets_sorted = tweets_filtered.sort_values(by='date', ignore_index=True)
tweets_sorted
# Out:
#                date                                               text
# 0        2021-07-30  @PedroCastilloTe Hablas igual a Diosdado cabel...
# 1        2021-07-30  @Camilita_evans @PedroCastilloTe @AlanGarciaPe...
# 2        2021-07-30  Si mañana fueran las elecciones, volvería a vo...
# 3        2021-07-30  @PedroCastilloTe solo queda sacar a Bellido, s...
# 4        2021-07-30  @ebelinortiz @PedroCastilloTe @KeikoFujimori A...
# ...             ...                                                ...
# 2197451  2022-04-28  @oscardiazperu @PedroCastilloTe Un cojudo a la...
# 2197452  2022-04-28  @Frospigliosi No le va a pasar nada a @PedroCa...
# 2197453  2022-04-28  #CarlosBasombrío en Canal N, critica al JNE po...
# 2197454  2022-04-28  #28Abr 🌎 | Pedro Castillo presentó propuesta p...
# 2197455  2022-04-28  @PTV_Noticias El "niñito" @ilichlopez2022 como...
#
# [2197456 rows x 2 columns]

# %% [markdown]
# Filter data by dates

# %%
tweets_by_day = tweets_sorted[tweets_sorted['date'] == '2022-04-28']
tweets_by_day
# Out:
#                date                                               text
# 2193926  2022-04-28  @majo_marcet @PedroCastilloTe Esto no es recie...
# 2193927  2022-04-28  @PedroCastilloTe @presidenciaperu @GobiernoPer...
# 2193928  2022-04-28  @Gahelatrans @claudiacisneros @PedroCastilloTe...
# 2193929  2022-04-28  @AnaeaEx @MaricarmenAlvaP @AAFPOficial @PedroC...
# 2193930  2022-04-28  🔴 AHORA | Consejo de Ministros descentralizado...
# ...             ...                                                ...
# 2197451  2022-04-28  @oscardiazperu @PedroCastilloTe Un cojudo a la...
# 2197452  2022-04-28  @Frospigliosi No le va a pasar nada a @PedroCa...
# 2197453  2022-04-28  #CarlosBasombrío en Canal N, critica al JNE po...
# 2197454  2022-04-28  #28Abr 🌎 | Pedro Castillo presentó propuesta p...
# 2197455  2022-04-28  @PTV_Noticias El "niñito" @ilichlopez2022 como...
#
# [3530 rows x 2 columns]

# %%
n_tweets_by_day = tweets_by_day.replace({'2021-09-24': '2021-09-25'})
n_tweets_by_day
# Out:
#               date                                               text
# 428518  2021-09-25  @ForsetiDios @GianDieztroGaaa @calipinedo @Ped...
# 428519  2021-09-25  @presidenciaperu @PedroCastilloTe @MindefPeru ...
# 428520  2021-09-25  @patriota_1972 Deberían de mandarle un par a n...
# 428521  2021-09-25        @PedroCastilloTe @CCFFAA_PERU Hipócritas!!!
# 428522  2021-09-25       @PedroCastilloTe @CCFFAA_PERU Fuera Bellido!
# ...            ...                                                ...
# 430997  2021-09-25  @Berto_Lopez69 @eudmed @PedroCastilloTe Ah, ok...
# 430998  2021-09-25  @MagalyNombert @EscapaCristian @sigridbazan @P...
# 430999  2021-09-25  @labitter_peru @ValAle15 @JosAntonioZav16 @exi...
# 431000  2021-09-25  Las inversiones se van por el comunismo del Pr...
# 431001  2021-09-25  @PedroCastilloTe @GuidoPuka @CancilleriaPeru @...
#
# [2484 rows x 2 columns]

# %% [markdown]
# Concatenation with all tweets dataset

# %%
new_tweets = pd.concat([new_tweets, n_tweets_by_day])
new_tweets.index = range(new_tweets.shape[0])
new_tweets
# Out:
#                date                                               text
# 0        2021-08-29  @Aldo_FD @PedroCastilloTe @GuidoPuka La corrup...
# 1        2021-08-29  @VLADIMIR_CERRON Cojudignos!!! Los que creyero...
# 2        2021-08-29  @asasperiodista @DeltaMdelta @PuntoFinalOf @VL...
# 3        2021-08-29    @carloswaite @PedroCastilloTe Tocará exorcizar.
# 4        2021-08-29  Eso no es todo sr. Presidente @PedroCastilloTe...
# ...             ...                                                ...
# 2240477  2021-07-28  @MesiasGuevara @presidenciaperu @PedroCastillo...
# 2240478  2021-07-28  Hey @PedroCastilloTe, recuerdas al pueblo? Est...
# 2240479  2021-07-28  @patarevalo @palidofuego111 @santoschilcano @A...
# 2240480  2021-07-28  Carlos Rua, gobernador de Ayacucho: “Nuestro p...
# 2240481  2021-07-28  @bettinaHuaral @PedroCastilloTe @Avelino_Guill...
#
# [2240482 rows x 2 columns]

# %%
n_tweets_sorted = new_tweets.sort_values(by='date', ignore_index=True)
n_tweets_sorted
# Out:
#                date                                               text
# 0        2021-07-28  @bettinaHuaral @PedroCastilloTe @Avelino_Guill...
# 1        2021-07-28  Si yo hubiera sido el presidente. Hubiera actu...
# 2        2021-07-28  @VktorR @anakdab @PedroCastilloTe Si es asi lo...
# 3        2021-07-28  @PedroCastilloTe Castillo para informarte que ...
# 4        2021-07-28  @canalN_ Para que???? Dios mio!! Tiene que nom...
# ...             ...                                                ...
# 2240477  2022-04-28  @oscardiazperu @PedroCastilloTe Un cojudo a la...
# 2240478  2022-04-28  @Frospigliosi No le va a pasar nada a @PedroCa...
# 2240479  2022-04-28  #CarlosBasombrío en Canal N, critica al JNE po...
# 2240480  2022-04-28  #28Abr 🌎 | Pedro Castillo presentó propuesta p...
# 2240481  2022-04-28  @canalN_ @PedroCastilloTe Renuncia ya #Castill...
#
# [2240482 rows x 2 columns]

# %% [markdown]
# # Iterative pipeline

# %%
cur_day = ['2021-07-30',
           '2021-07-30',
           '2021-09-24',
           '2021-10-11',
           '2021-11-06',
           '2021-12-14',
           '2022-01-17',
           '2022-01-31',
           '2022-02-16',
           '2022-02-24',
           '2022-03-13',
           '2022-03-29',
           '2022-03-29',
           '2022-04-03',
           '2022-04-03',
           '2022-04-27',
           '2022-04-27']
new_day = ['2021-07-28',
           '2021-07-29',
           '2021-09-25',
           '2021-10-10',
           '2021-11-07',
           '2021-12-13',
           '2022-01-16',
           '2022-01-30',
           '2022-02-15',
           '2022-02-23',
           '2022-03-12',
           '2022-03-30',
           '2022-03-31',
           '2022-04-01',
           '2022-04-02',
           '2022-04-29',
           '2022-04-30']

tweets_by_day = tweets_sorted[tweets_sorted['date'] == cur_day[0]]
print(tweets_by_day.shape)
n_tweets_by_day = tweets_by_day.replace({cur_day[0]: new_day[0]})
new_tweets = pd.concat([tweets_sorted, n_tweets_by_day])
new_tweets.index = range(new_tweets.shape[0])
n_tweets_sorted = new_tweets.sort_values(by='date', ignore_index=True)

for i in range(1, len(new_day)):
  tweets_by_day = tweets_sorted[tweets_sorted['date'] == cur_day[i]]
  print(tweets_by_day.shape)
  n_tweets_by_day = tweets_by_day.replace({cur_day[i]: new_day[i]})
  new_tweets = pd.concat([new_tweets, n_tweets_by_day])
  new_tweets.index = range(new_tweets.shape[0])
  n_tweets_sorted = new_tweets.sort_values(by='date', ignore_index=True)

n_tweets_sorted
# Out:
# (21513, 2)
# (21513, 2)
# (2484, 2)
# (397, 2)
# (4237, 2)
# (2666, 2)
# (2722, 2)
# (2930, 2)
# (4070, 2)
# (1022, 2)
# (875, 2)
# (11820, 2)
# (11820, 2)
# (6857, 2)
# (6857, 2)
# (8022, 2)
# (8022, 2)
#                date                                               text
# 0        2021-07-28  @PedroCastilloTe Hablas igual a Diosdado cabel...
# 1        2021-07-28  @ebelinortiz @PedroCastilloTe @KeikoFujimori Y...
# 2        2021-07-28  #Perù #México Pedro Castillo desafía a Perú co...
# 3        2021-07-28  @Perulibreprensa NOS MENTISTE @PedroCastilloTe...
# 4        2021-07-28  Parece que a alguien le gustó escuchar que "ha...
# ...             ...                                                ...
# 2315278  2022-04-30  @RichardArcePeru @PedroCastilloTe Es un gobier...
# 2315279  2022-04-30  @JorgeMunozPe @JNE_Peru Ahora sería bueno que ...
# 2315280  2022-04-30  @NoDignos @PedroCastilloTe @congresoperu Jsjsjsjs
# 2315281  2022-04-30  Now playing Pedro Castillo aosto 13,2021 by Pe...
# 2315282  2022-04-30  @radio_santarosa @rmapalacios @PedroCastilloTe...
#
# [2315283 rows x 2 columns]

# %%
n_tweets_date = n_tweets_sorted.copy()
n_tweets_date['date'] = pd.to_datetime(n_tweets_date['date'])

# %%
n_tweets_date["my_day"] = n_tweets_date.date.dt.date

# %%
for day, datos in n_tweets_date.groupby("my_day"):
  print("{}: {}".format(day, len(datos)))
# Out:
# 2021-07-28: 21513
# 2021-07-29: 21513
# 2021-07-30: 21513
# 2021-07-31: 13787
# 2021-08-01: 14659
# 2021-08-02: 11214
# 2021-08-03: 9933
# 2021-08-04: 10011
# 2021-08-05: 10072
# 2021-08-06: 9739
# 2021-08-07: 6383
# 2021-08-08: 6205
# 2021-08-09: 7155
# 2021-08-10: 6993
# 2021-08-11: 8345
# 2021-08-12: 9047
# 2021-08-13: 6166
# 2021-08-14: 5855
# 2021-08-15: 9431
# 2021-08-16: 5954
# 2021-08-17: 7491
# 2021-08-18: 11441
# 2021-08-19: 7048
# 2021-08-20: 11033
# 2021-08-21: 6610
# 2021-08-22: 5249
# 2021-08-23: 6349
# 2021-08-24: 6035
# 2021-08-25: 11281
# 2022-04-28: 3530
# 2022-04-29: 8022
# 2022-04-30: 8022

# %% [markdown]
# Save the tweets completed

# %%
n_tweets_sorted
# Out:
#                date                                               text
# 0        2021-07-28  @PedroCastilloTe Hablas igual a Diosdado cabel...
# 1        2021-07-28  @ebelinortiz @PedroCastilloTe @KeikoFujimori Y...
# 2        2021-07-28  #Perù #México Pedro Castillo desafía a Perú co...
# 3        2021-07-28  @Perulibreprensa NOS MENTISTE @PedroCastilloTe...
# 4        2021-07-28  Parece que a alguien le gustó escuchar que "ha...
# ...             ...                                                ...
# 2315278  2022-04-30  @RichardArcePeru @PedroCastilloTe Es un gobier...
# 2315279  2022-04-30  @JorgeMunozPe @JNE_Peru Ahora sería bueno que ...
# 2315280  2022-04-30  @NoDignos @PedroCastilloTe @congresoperu Jsjsjsjs
# 2315281  2022-04-30  Now playing Pedro Castillo aosto 13,2021 by Pe...
# 2315282  2022-04-30  @radio_santarosa @rmapalacios @PedroCastilloTe...
#
# [2315283 rows x 2 columns]

# %%
n_tweets_sorted.to_json("/content/drive/MyDrive/UCSP/Data-Science-Topics/Data/all_tweets.json", index=False, orient="split")

# %% [markdown]
# Check the tweets file.

# %%
test = pd.read_json("/content/drive/MyDrive/UCSP/Data-Science-Topics/Data/all_tweets.json", orient="split")
test
# Out:
#               date                                               text
# 0       2021-07-28  @PedroCastilloTe Hablas igual a Diosdado cabel...
# 1       2021-07-28  @ebelinortiz @PedroCastilloTe @KeikoFujimori Y...
# 2       2021-07-28  #Perù #México Pedro Castillo desafía a Perú co...
# 3       2021-07-28  @Perulibreprensa NOS MENTISTE @PedroCastilloTe...
# 4       2021-07-28  Parece que a alguien le gustó escuchar que "ha...
# ...            ...                                                ...
# 2315278 2022-04-30  @RichardArcePeru @PedroCastilloTe Es un gobier...
# 2315279 2022-04-30  @JorgeMunozPe @JNE_Peru Ahora sería bueno que ...
# 2315280 2022-04-30  @NoDignos @PedroCastilloTe @congresoperu Jsjsjsjs
# 2315281 2022-04-30  Now playing Pedro Castillo aosto 13,2021 by Pe...
# 2315282 2022-04-30  @radio_santarosa @rmapalacios @PedroCastilloTe...
#
# [2315283 rows x 2 columns]

# %%
test['date'] = pd.to_datetime(test.date)
test["my_day"] = test.date.dt.date
for day, datos in test.groupby("my_day"):
  print("{}: {}".format(day, len(datos)))
# Out:
# 2021-07-28: 21513
# 2021-07-29: 21513
# 2021-07-30: 21513
# 2021-07-31: 13787
# 2021-08-01: 14659
# 2021-08-02: 11214
# 2021-08-03: 9933
# 2021-08-04: 10011
# 2021-08-05: 10072
# 2021-08-06: 9739
# 2021-08-07: 6383
# 2021-08-08: 6205
# 2021-08-09: 7155
# 2021-08-10: 6993
# 2021-08-11: 8345
# 2021-08-12: 9047
# 2021-08-13: 6166
# 2021-08-14: 5855
# 2021-08-15: 9431
# 2021-08-16: 5954
# 2021-08-17: 7491
# 2021-08-18: 11441
# 2021-08-19: 7048
# 2021-08-20: 11033
# 2021-08-21: 6610
# 2021-08-22: 5249
# 2021-08-23: 6349
# 2021-08-24: 6035
# 2021-08-25: 11281
# 2021-08-26: 4902
# 2021-08-27: 6162
# 2021-08-28: 4414
