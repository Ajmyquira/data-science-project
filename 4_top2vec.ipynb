# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Getting the tweets processed.

# %%
import pandas as pd

tweets = pd.read_json("/content/drive/MyDrive/UCSP/Data-Science-Topics/Data/tweets_text_processed.json", orient="split")
tweets
# Out:
#               date                                     text_processed
# 0       2021-07-28      hablas diosdado cabello chavez maduro castros
# 1       2021-07-28  gente necios evidencias siguen creyendo cuento...
# 2       2021-07-28  u exico desafia peru nombramiento gabinete rad...
# 3       2021-07-28  mentiste representa opuesto discurso abiertame...
# 4       2021-07-28       alguien gusto escuchar habra trenes discurso
# ...            ...                                                ...
# 2166124 2022-04-30  gobierno incapaz corrupto ademas indolente pueblo
# 2166125 2022-04-30                              seria encabece marcha
# 2166126 2022-04-30                                           jsjsjsjs
# 2166127 2022-04-30                               now playing aosto by
# 2166128 2022-04-30                                     entrevista dra
#
# [2166129 rows x 2 columns]

# %%
tweets_by_month = tweets.copy()
tweets_by_month["month"] = tweets_by_month.date.dt.month
tweets_by_month
# Out:
#               date                                     text_processed  month
# 0       2021-07-28      hablas diosdado cabello chavez maduro castros      7
# 1       2021-07-28  gente necios evidencias siguen creyendo cuento...      7
# 2       2021-07-28  u exico desafia peru nombramiento gabinete rad...      7
# 3       2021-07-28  mentiste representa opuesto discurso abiertame...      7
# 4       2021-07-28       alguien gusto escuchar habra trenes discurso      7
# ...            ...                                                ...    ...
# 2166124 2022-04-30  gobierno incapaz corrupto ademas indolente pueblo      4
# 2166125 2022-04-30                              seria encabece marcha      4
# 2166126 2022-04-30                                           jsjsjsjs      4
# 2166127 2022-04-30                               now playing aosto by      4
# 2166128 2022-04-30                                     entrevista dra      4
#
# [2166129 rows x 3 columns]

# %%
tweets_list = []

for i, _tweets in tweets_by_month.groupby('month'):
  tweets_list.append(pd.DataFrame(_tweets[['date', 'text_processed']]))

# %% [markdown]
# To install pre-trained universal sentence encoder options

# %%
# !pip install -q top2vec[sentence_encoders]
# Out:
#      |████████████████████████████████| 24.1 MB 59.8 MB/s
#      |████████████████████████████████| 88 kB 7.8 MB/s
#      |████████████████████████████████| 5.2 MB 35.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 4.6 MB 35.0 MB/s
#      |████████████████████████████████| 1.1 MB 61.4 MB/s
#      |████████████████████████████████| 511.7 MB 5.9 kB/s
#      |████████████████████████████████| 511.7 MB 4.4 kB/s
#      |████████████████████████████████| 4.9 MB 21.6 MB/s
# ...

# %% [markdown]
# Select the data by month following:
# - 0: enero
# - 1: febrero
# - 2: marzo
# - 3: abril
# - 4: julio
# - 5: agosto
# - 6: septiembre
# - 7: octubre
# - 8: noviembre
# - 9: diciembre

# %%
temp = tweets_list[3].reset_index(drop=True)  # Abril
temp
# Out:
#              date                                     text_processed
# 0      2022-04-01  investigar responsable vio canal n niño corria...
# 1      2022-04-01                                         rico webeo
# 2      2022-04-01  venezuela destrozado economia latinoamerica ge...
# 3      2022-04-01  solucion origen males minimizado asesinado niñ...
# 4      2022-04-01  urgente impuesto sobreganancias utilidades net...
# ...           ...                                                ...
# 260253 2022-04-30  gobierno incapaz corrupto ademas indolente pueblo
# 260254 2022-04-30                              seria encabece marcha
# 260255 2022-04-30                                           jsjsjsjs
# 260256 2022-04-30                               now playing aosto by
# 260257 2022-04-30                                     entrevista dra
#
# [260258 rows x 2 columns]

# %% [markdown]
# Generate two separate lists of tweets and dates.

# %%
_tweets = []
_dates = []

for i in range(len(temp)):
  _tweets.append(temp['text_processed'][i])
  _dates.append(temp['date'][i])

print(len(_tweets))
print(len(_dates))
# Out:
# 260258
# 260258

# %% [markdown]
# Run the Top2Vec

# %%
from top2vec import Top2Vec

model = Top2Vec(_tweets, embedding_model='universal-sentence-encoder-multilingual')
model.save("/content/drive/MyDrive/UCSP/Data-Science-Topics/Final-project/Top2Vec-models/model-09")
# Out:
# 2022-07-09 00:02:51,724 - top2vec - INFO - Pre-processing documents for training
# INFO:top2vec:Pre-processing documents for training
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 2022-07-09 00:03:06,686 - top2vec - INFO - Downloading universal-sentence-encoder-multilingual model
# INFO:top2vec:Downloading universal-sentence-encoder-multilingual model
# 2022-07-09 00:03:11,634 - top2vec - INFO - Creating joint document/word embedding
# INFO:top2vec:Creating joint document/word embedding
# 2022-07-09 00:11:43,941 - top2vec - INFO - Creating lower dimension embedding of documents
# INFO:top2vec:Creating lower dimension embedding of documents
# 2022-07-09 00:22:53,988 - top2vec - INFO - Finding dense areas of documents
# ...
